# %% [markdown]
# Q1. Wh
# t is
# n Ex,eption in p
#
# thon? Write the differen,e etween Ex,eptions
# nd $
# nt
# x errors
#
# Ans- Exception occours during the execution of the code when error or exception condition occurs. Syntex error occurs while parsing the code.

# %% [markdown]
# Q2. Wh
# t h
# ppens when
#
# n exeption is not h
#
# ndled? Expl
# in with
# n ex
# mple
#
# Ans- When Excpetion is not handled then the complier will stop executing and not process the further codes.
# Eg- print('Start of Program')
# a,b = 2,0
# T = a/b
# print("End of Code")
# Here the program will throw error of- division by zero and will only print start of program as output

# %% [markdown]
# Q3. Whi,h P
# thon st
# tements
#
# re used to ,
# t,h
# nd h
# ndle ex,eptions? Expl
# in with
# n ex
# mple
#
# Ans- Try - Except staatements to handle exceptions.
# print('Start of Program')
# try:
#     a,b = 2,0
#     T = a/b
# except ZeroDivisionError as e:
#     print(e)
# print("End of Code")

# %% [markdown]
# Q4. Expl
# in with
# n ex
# mple:#
#
#  tr
# nd else#
#  fin
# ll
# + r
# ise
#
# Ans- a)Try and else
# def divide_numbers(a, b):
#     try:
#         result = a / b
#     except ZeroDivisionError:
#         print("Error: Division by zero is not allowed!")
#     else:
#         print("Result:", result)
#
# num1 = 10
# num2 = 2
#
# divide_numbers(num1, num2)
#
# b)Finally:
# def divide_numbers(a, b):
#     try:
#         result = a / b
#         print("Result:", result)
#     except ZeroDivisionError:
#         print("Error: Division by zero is not allowed!")
#     finally:
#         print("Finally block executed.")
#
# num1 = 10
# num2 = 0
#
# divide_numbers(num1, num2)
#
# c)rise
# def validate_age(age):
#     if age < 0:
#         raise ValueError("Age cannot be negative.")
#     elif age < 18:
#         raise Exception("You must be 18 years or older.")
#
# try:
#     age = -5
#     validate_age(age)
# except ValueError as ve:
#     print(ve)
# except Exception as e:
#     print(e)

# %% [markdown]
# Q5. Wh
# t
# re Custom Ex,eptions in p
#
# thon? Wh
#
# do we need Custom Ex,eptions? Expl
# in with
# n ex
# mple
#
# And-class InsufficientFundsError(Exception):
#     pass
#
# class BankAccount:
#     def __init__(self, balance):
#         self.balance = balance
#
#     def withdraw(self, amount):
#         if amount > self.balance:
#             raise InsufficientFundsError("Insufficient funds to make the withdrawal.")
#         self.balance -= amount
#         print("Withdrawal successful. Remaining balance:", self.balance)
#
# account = BankAccount(1000)
# try:
#     account.withdraw(1500)
# except InsufficientFundsError as e:
#     print(e)
